# %% [markdown]
# # Opreator:
# ## defination:
# A symbol that tells the interpreter to perform specific mathematical or logical manipulations.
#  Examples: +, -, *, /, %, **, //
# ## Important Operators in Python:
# 1. Arithmetic Operators: +, -, *, /, %, **, //
# 2. Comparison Operators: ==, !=, >, <, >=, <=
# 3. Logical Operators: and, or, not
# 4. Assignment Operators: =, +=, -=, *=, /=, %=
# 5. Bitwise Operators: &, |, ^, ~, <<, >>
# 6. Membership Operators: in, not in
# 7. Identity Operators: is, is not

# %%
## Arithmetic Operations
a = 10
b = 3
sum_result = a + b
print("Sum:", sum_result)

# Subtraction
sub_result = a - b
print("Subtraction:", sub_result)

# Multiplication
mul_result = a * b
print("Multiplication:", mul_result)

# Division
div_result = a / b
print("Division:", div_result)

# Floor Division
floor_div_result = a // b
print("Floor Division:", floor_div_result)

# Modulus
mod_result = a % b
print("Modulus:", mod_result)

# Exponentiation
exp_result = a ** b
print("Exponentiation:", exp_result)

## Operator Precedence
result = 10 + 2 * 5
print("Result without parentheses:", result)
result_with_parentheses = (10 + 2) * 5
# Out:
# Sum: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000
# Result without parentheses: 20

# %%
## Logical Operators
a = True
b = False
and_result = a and b
print("AND Result:", and_result)
or_result = a or b
print("OR Result:", or_result)
not_result = not a
print("NOT Result:", not_result)
print("Result with parentheses:", result_with_parentheses)
# Out:
# AND Result: False
# OR Result: True
# NOT Result: False
# Result with parentheses: 60

# %%
## comparison operators
x = 10
y = 20
print("x == y:", x == y)
print("x != y:", x != y)
print("x > y:", x > y)
print("x < y:", x < y)
print("x >= y:", x >= y)
# Out:
# x == y: False
# x != y: True
# x > y: False
# x < y: True
# x >= y: False

# %%
## Bitwise Operators
a = 5  # Binary: 0101
b = 3  # Binary: 0011
and_result = a & b  # Binary: 0001
print("Bitwise AND:", and_result)
or_result = a | b   # Binary: 0111
print("Bitwise OR:", or_result)
xor_result = a ^ b  # Binary: 0110
print("Bitwise XOR:", xor_result)
# Out:
# Bitwise AND: 1
# Bitwise OR: 7
# Bitwise XOR: 6

# %%
S
