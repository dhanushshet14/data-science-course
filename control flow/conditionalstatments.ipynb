# %%
# conditional statements
# types of conditional statements
# if statement
x = 10
if x > 5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
#if statement with else
x = 3
if x > 5:
    print("x is greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
#elif statement
x = 15
if x < 10:
    print("x is less than 10")
elif x < 20:
    print("x is between 10 and 20")
else:
    print("x is 20 or more")
#else if ladder
# Out:
# x is between 10 and 20

# %%
# Nested conditional statements
x = 25
if x > 10:
    if x < 30:
        print("x is between 10 and 30")
    else:
        print("x is 30 or more")
# Out:
# x is between 10 and 30

# %%
## common error and best practices
# Avoid using assignment operator (=) instead of comparison operator (==)
# Use proper indentation to avoid IndentationError
# Use parentheses to clarify complex conditions

# %%
## Practice Exercises
 ##determine if a year is a leap year or not usin nested conditional statements. let the user enter the input 
year = int(input("Enter a year: "))
if (year % 4) == 0:
    if (year % 100) == 0:
        if (year % 400) == 0:
            print(f"{year} is a leap year")
        else:
            print(f"{year} is not a leap year")
    else:
        print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 2024 is a leap year
